# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("IMDB-Movie-Data.csv", index_col= "Title")

# %%
data.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %%
data.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
# Extract as series
genre = data["Genre"]
genre
# Out:
# Title
# Guardians of the Galaxy     Action,Adventure,Sci-Fi
# Prometheus                 Adventure,Mystery,Sci-Fi
# Split                               Horror,Thriller
# Sing                        Animation,Comedy,Family
# Suicide Squad              Action,Adventure,Fantasy
#                                      ...
# Secret in Their Eyes            Crime,Drama,Mystery
# Hostel: Part II                              Horror
# Step Up 2: The Streets          Drama,Music,Romance
# Search Party                       Adventure,Comedy
# Nine Lives                    Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object

# %%
# Extract as dataframe
genre_dataframe = data[["Genre"]]
genre_dataframe
# Out:
#                                             Genre
# Title
# Guardians of the Galaxy   Action,Adventure,Sci-Fi
# Prometheus               Adventure,Mystery,Sci-Fi
# Split                             Horror,Thriller
# Sing                      Animation,Comedy,Family
# Suicide Squad            Action,Adventure,Fantasy
# ...                                           ...
# Secret in Their Eyes          Crime,Drama,Mystery
# Hostel: Part II                            Horror
# Step Up 2: The Streets        Drama,Music,Romance
# Search Party                     Adventure,Comedy
# Nine Lives                  Comedy,Family,Fantasy
#
# [1000 rows x 1 columns]

# %%
some_cols = data[["Genre", "Actors", "Director", "Rating"]]
some_cols
# Out:
#                                             Genre  \
# Title
# Guardians of the Galaxy   Action,Adventure,Sci-Fi
# Prometheus               Adventure,Mystery,Sci-Fi
# Split                             Horror,Thriller
# Sing                      Animation,Comedy,Family
# Suicide Squad            Action,Adventure,Fantasy
# ...                                           ...
# Secret in Their Eyes          Crime,Drama,Mystery
# Hostel: Part II                            Horror
# Step Up 2: The Streets        Drama,Music,Romance
# Search Party                     Adventure,Comedy
# Nine Lives                  Comedy,Family,Fantasy
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Split                    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# ...

# %%
slicing_data = data.iloc[10:15][["Genre", "Actors", "Director", "Rating"]]
slicing_data
# Out:
#                                                               Genre  \
# Title
# Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# Hidden Figures                              Biography,Drama,History
# Rogue One                                   Action,Adventure,Sci-Fi
# Moana                                    Animation,Adventure,Comedy
# Colossal                                        Action,Comedy,Drama
#
#                                                                                     Actors  \
# Title
# Fantastic Beasts and Where to Find Them  Eddie Redmayne, Katherine Waterston, Alison Su...
# Hidden Figures                           Taraji P. Henson, Octavia Spencer, Janelle Mon...
# Rogue One                                Felicity Jones, Diego Luna, Alan Tudyk, Donnie...
# Moana                                    Auli'i Cravalho, Dwayne Johnson, Rachel House,...
# ...

# %%
conditional_filtering = data[((data["Year"] >= 2010) & (data["Year"] <= 2015))
                             & (data["Rating"] < 6.0)
                             & (data["Revenue (Millions)"] > data["Revenue (Millions)"].quantile(0.95))]
conditional_filtering
# Out:
#                             Rank                    Genre  \
# Title
# The Twilight Saga: Eclipse   942  Adventure,Drama,Fantasy
#
#                                                                   Description  \
# Title
# The Twilight Saga: Eclipse  As a string of mysterious killings grips Seatt...
#
#                                Director  \
# Title
# The Twilight Saga: Eclipse  David Slade
#
#                                                                        Actors  \
# Title
# The Twilight Saga: Eclipse  Kristen Stewart, Robert Pattinson, Taylor Laut...
#
#                             Year  Runtime (Minutes)  Rating   Votes  \
# Title
# The Twilight Saga: Eclipse  2010                124     4.9  192740
#
#                             Revenue (Millions)  Metascore
# Title
# The Twilight Saga: Eclipse              300.52       58.0

# %%
group_data_mean_director = data.groupby("Director")[["Rating"]].mean().head()
group_data
# Out:
#                      Rating
# Director
# Aamir Khan              8.5
# Abdellatif Kechiche     7.8
# Adam Leon               6.5
# Adam McKay              7.0
# Adam Shankman           6.3

# %%
group_data_sorting_director = data.groupby("Director")[["Rating"]].mean().sort_values(["Rating"], ascending= False).head()
group_data_sorting_director
# Out:
#                                   Rating
# Director
# Nitesh Tiwari                       8.80
# Christopher Nolan                   8.68
# Olivier Nakache                     8.60
# Makoto Shinkai                      8.60
# Florian Henckel von Donnersmarck    8.50

# %%
missing_value = data.isnull().sum()
missing_value
# Out:
# Rank                    0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
filling_missing_value_col_deleting = data.drop("Metascore", axis= 1).describe()
filling_missing_value_col_deleting
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)
# count          872.000000
# mean            82.956376
# std            103.253540
# min              0.000000
# 25%             13.270000
# 50%             47.985000
# 75%            113.715000
# max            936.630000

# %%
filling_missing_value_row_deleting = data.dropna().count()
filling_missing_value_row_deleting
# Out:
# Rank                  838
# Genre                 838
# Description           838
# Director              838
# Actors                838
# Year                  838
# Runtime (Minutes)     838
# Rating                838
# Votes                 838
# Revenue (Millions)    838
# Metascore             838
# dtype: int64

# %%
# Split rating following good, average, bad
def rating_group(rating):
    if rating >= 7.5:
        return "Good"
    elif rating >= 6.0:
        return "Average"
    else:
        return "Bad"

data["Rating_category"] = data["Rating"].apply(rating_group)

data[["Director", "Rating", "Rating_category"]].head()
# Out:
#                                      Director  Rating Rating_category
# Title
# Guardians of the Galaxy            James Gunn     8.1            Good
# Prometheus                       Ridley Scott     7.0         Average
# Split                      M. Night Shyamalan     7.3         Average
# Sing                     Christophe Lourdelet     7.2         Average
# Suicide Squad                      David Ayer     6.2         Average
